# %%
import os
import re
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm

# Plotly
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Get list of file names in the directory

# %%
filename = os.listdir('data')
# get length of the list
filename
# Out:
# ['watchedVideo.csv',
#  '.DS_Store',
#  'feeds.csv',
#  'users.csv',
#  'videos.csv',
#  'tables.txt']

# %% [markdown]
# ## User data

# %%
users = pd.read_csv('data/users.csv')
users.head()
# Out:
#    Unnamed: 0                                    id           created_at  \
# 0           0  37e369a8-4477-4d5d-acd7-4e3b8059586e  2021-03-23 00:24:53
# 1           1  27cf0bb6-3488-4662-916d-3ad04eeec9ca  2021-04-09 19:55:07
# 2           2  5ebd5e12-ba2a-4bf9-b7e4-92ad24711cd4  2021-04-08 21:48:45
# 3           3  30986592-0cbf-43bb-83ed-7501ab3bd373  2021-05-15 00:45:51
# 4           4  25b49125-34d1-4694-a4a9-8415bcc3567b  2021-07-05 04:08:53
#
#          class                coordinates
# 0      Creator    ('36.76775', '2.95924')
# 1       Viewer   ('43.71032', '-1.05366')
# 2  Super Gamer       ('51.26', '-2.1875')
# 3      Creator  ('40.65538', '-74.38987')
# 4       Viewer  ('35.61452', '-88.81395')

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   id           1000 non-null   object
#  2   created_at   1000 non-null   object
#  3   class        1000 non-null   object
#  4   coordinates  1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
users = users.drop('Unnamed: 0', axis=1)

# %%
users.groupby('class')['id'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='class'>

# %%
users['class'].unique()
# Out:
# array(['Creator', 'Viewer', 'Super Gamer', 'Super Creator', 'Gamer'],
#       dtype=object)

# %%
users.groupby('class').count()
# Out:
#                Unnamed: 0   id  created_at  coordinates
# class
# Creator               186  186         186          186
# Gamer                 213  213         213          213
# Super Creator         206  206         206          206
# Super Gamer           209  209         209          209
# Viewer                186  186         186          186

# %%
px.bar(users, x=id, )

# %%
users['lat'] = users.coordinates.apply(lambda x: float(x.split(',')[0][2:-1]))

# %%
users['long'] = users.coordinates.apply(lambda x: float(x.split(',')[1][2:-2]))

# %%
BBox = (users.long.min(), users.long.max(), users.lat.min(), users.lat.max())
BBox
# Out:
# (-122.86705, 178.00417, -54.8, 68.79833)

# %% [markdown]
# #### Plot user geographical location

# %%
fig = go.Figure()
fig = px.scatter(users, x='long', y='lat', color='class')
# fig.add_trace(go.Scatter(x=users['lat'], y=users['long'], mode='markers'))
fig.add_layout_image(
    dict(
        source='https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/No_colonies_blank_world_map.png/1200px-No_colonies_blank_world_map.png',
        xref="x",
        yref="y",
        x=-140,
        y=85,
        sizex=345,
        sizey=144,
        opacity=0.5,
        sizing='stretch',
        layer='below'))

fig.update_traces(marker=dict(size=10),
                  selector=dict(mode='markers'))
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.update_layout(template="plotly_white")
fig.show()
# Out:
# <div>                            <div id="b55add6f-8c34-4e9e-afb4-9ce87841b342" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b55add6f-8c34-4e9e-afb4-9ce87841b342")) {                    Plotly.newPlot(                        "b55add6f-8c34-4e9e-afb4-9ce87841b342",                        [{"hovertemplate":"class=Creator<br>long=%{x}<br>lat=%{y}<extra></extra>","legendgroup":"Creator","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"Creator","orientation":"v","showlegend":true,"x":[2.95924,-74.38987,86.79271,38.02486,34.02537,14.66737,10.78222,24.43973,-95.63079,4.18333,-38.79084,122.22833,101.96857,5.22778,35.7,1.26738,9.5926,99.89166,12.70038,-122.40433,116.11768,84.87144,2.95924,71.30633,109.3243,22.53083,38.66667,24.71204,-80.22588,-45.94722,109.05389,59.80222,-90.10674,-99.32556,30.4347,73.7553,6.9747,-103.42897,-93.08883,-78.87836,145.06667,-3.67029,136.84186,-117.14392,-42.19667,5.22778,-80.58556,36.7138,-42.19667,-3.05814,1.00288,78.95693,34.37389,-111.78903,76.32756,101.44167,83.36889,85.83636,-118.25508,-118.10583,57.3552,-75.60804,-1.08593,-83.2321,86.68363,114.51667,76.92421,75.11937,27.46153,73.7553,-74.13653,12.38878,101.44167,121.12251,86.00214,120.74221,-91.73625,33.2525,34.02537,117.7,-1.08593,76.35484,3.55665,-81.38758,109.22921,104.64992,68.88871,-74.38987,41.77921,79.41727,-81.23621,101.44167,-75.64963,3.55665,-82.42491,5.23333,137.23333,10.18003,14.39024,70.91106,-104.22884,-48.29694,140.72287,153.10236,-95.30106,11.34046,-2.98884,17.4674,-73.89875,-41.25528,-15.58602,-88.27205,68.49143,153.10236,6.10237,135.6,-75.64963,-99.32556,-43.80139,59.6,-63.13414,141.95,130.57211,19.91667,28.88222,78.40102,-117.70755,-80.22588,10.03988,11.5,-75.11028,-70.92866,-88.31476,-84.67837,-0.76773,120.56528,75.16878,78.27539,-85.76942,-6.90656,-101.2591,-73.0515,9.00472,-2.77259,126.665,-77.55777,-86.99666,6.26667,10.18527,98.6738,-48.59278,-86.58208,3.47717,6.92917,-42.98194,-48.59278,27.25,2.08333,-100.88023,6.51352,123.758,-100.44843,-6.03731,78.95693,-96.67834,84.87144,13.31783,-48.67028,2.08333,-122.24064,-80.08199,-49.27306,-87.45476,100.04427,120.14278,-51.50361,-67.33122,-5.22126,36.73307,-116.37697,-1.32471,37.3825,-79.00453,32.88667,-111.78903,53.47103],"xaxis":"x","y":[36.76775,40.65538,25.92127,55.64776,38.37255,41.55947,36.46917,0.76755,31.76212,7.6,-10.95817,40.66482,4.88441,51.955,-7.76667,51.84819,52.86147,15.46063,45.9836,37.71715,24.28859,47.46657,36.76775,21.34222,-7.0981,44.22639,-6.25,41.57439,26.2173,-21.42917,-7.51611,58.63667,29.84576,19.32889,-1.9487,15.5439,50.82709,20.28527,45.16024,35.05266,-37.88333,37.13548,34.4833,32.9156,-21.41222,51.955,22.98212,35.95664,-21.41222,53.00974,49.28669,29.21399,40.1675,33.35283,9.57046,0.51667,26.76628,25.66795,34.14251,34.09611,51.4781,39.96097,50.79205,33.08014,23.49668,33.78333,60.97944,20.88098,-21.44236,15.5439,40.63316,43.1122,0.51667,14.62578,46.51872,31.64615,35.25064,57.97472,38.37255,35.85,50.79205,10.10649,36.72544,30.17746,34.65918,14.64056,25.95533,40.65538,41.82143,12.25282,33.98154,0.51667,40.24537,36.72544,42.97086,52.09,35.8,24.96334,42.22718,29.38242,32.42067,-20.87306,53.14657,-27.50578,32.35126,50.72043,43.32686,50.86079,40.93121,-19.32556,27.76056,44.27804,25.80565,-27.50578,46.18396,34.61667,40.24537,19.32889,-20.25333,47.83333,46.23899,39.46667,45.75279,-11.78333,40.37528,27.9247,33.52253,26.2173,53.6052,3.51667,-15.21194,42.52787,36.61033,34.06635,38.38479,14.66,30.81383,12.95629,39.78504,33.92866,21.01858,41.55815,4.2475,37.49073,36.6009,37.52487,33.45122,51.21667,47.98372,3.7278,-23.7975,13.48082,36.76639,52.31333,-22.53722,-23.7975,42.7,48.86667,20.21322,51.19139,10.20898,20.74122,37.35813,29.21399,34.77453,47.46657,52.61131,-28.24,48.86667,47.80527,35.88264,-25.42778 ...

# %%
from geopy.geocoders import Nominatim
from geopy.point import Point

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
location = lambda x: geolocator.reverse(x['lat']+','+x['long'])

# %%
lat = users.iloc[0]['lat']
long = users.iloc[0]['long']

# %%
location = geolocator.reverse(Point(lat, long))

# %%
address = location.raw['address']
print(address)
# Out:
# {'amenity': 'Café Le Mignon', 'road': 'Rue Arbadji Salah', 'hamlet': 'Résidence el noor', 'city': 'Cheraga ⵛⴻⵔⵔⴰⴳⴰ الشراقة', 'county': 'Cheraga', 'state': 'Alger الجزائر', 'ISO3166-2-lvl4': 'DZ-16', 'postcode': '16018', 'country': 'Algérie / ⵍⵣⵣⴰⵢⴻⵔ / الجزائر', 'country_code': 'dz'}

# %%
def get_country_code(lat, long):
    geolocator = Nominatim(user_agent="geoapiExercises")
    location = geolocator.reverse(Point(lat, long))
    if location:
        address = location.raw['address']
        country_code = address.get('country_code', '')
        return country_code
    return

# %%
tqdm.tqdm.pandas()

# %%
users['country_code'] = users.progress_apply(lambda users: get_country_code(users['lat'], users['long']), axis=1)
# Out:
# 100%|██████████| 1000/1000 [08:13<00:00,  2.03it/s]

# %% [markdown]
# ### Feeds Data

# %%
feeds = pd.read_csv('data/feeds.csv')
feeds
# Out:
#    Unnamed: 0                                    id     name
# 0           0  27a87df4-da75-451f-b8f6-af9dd0a4ee00    music
# 1           1  42568c8a-efbe-4293-81a3-513e33094ade  fashion
# 2           2  6894af29-56cc-4b4a-8ee6-be9b3cb3e7f1   sports
# 3           3  c9d59470-c4ee-43ff-831d-b52508c8d848    games
# 4           4  582520b2-b30a-4ecb-b1b4-1806672fcfc4   travel
# 5           5  a8a04865-55d4-4de4-8141-b273b678299f      fun
# 6           6  644a3cb6-e266-4757-9e96-a3ee049216fe    jokes
# 7           7  da6c201f-8e50-433c-b2ad-614e42fac047     love
# 8           8  8078efe7-5bae-4528-9a66-b85904cc73ac    dance
# 9           9  30134b9e-1b79-43fb-b0c5-373af9237b2c  beaches

# %%
feeds = feeds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ### Videos Data

# %%
videos = pd.read_csv('data/videos.csv')
videos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    5000 non-null   int64
#  1   id            5000 non-null   object
#  2   attribute_id  5000 non-null   object
#  3   music_id      5000 non-null   object
#  4   animation_id  5000 non-null   object
#  5   duration      5000 non-null   float64
#  6   creator       5000 non-null   object
#  7   created_at    5000 non-null   object
#  8   num_shares    5000 non-null   int64
#  9   game_id       5000 non-null   object
#  10  is_ar         5000 non-null   bool
# dtypes: bool(1), float64(1), int64(2), object(7)
# memory usage: 395.6+ KB

# %%
videos = videos.drop('Unnamed: 0', axis=1)

# %%
videos.columns
# Out:
# Index(['id', 'attribute_id', 'music_id', 'animation_id', 'duration', 'creator',
#        'created_at', 'num_shares', 'game_id', 'is_ar'],
#       dtype='object')

# %%
pd.merge(videos, users[['id', 'class']], left_on='creator', right_on='id').groupby('class').count()
# Out:
#                id_x  attribute_id  music_id  animation_id  duration  creator  \
# class
# Creator         963           963       963           963       963      963
# Gamer          1078          1078      1078          1078      1078     1078
# Super Creator  1015          1015      1015          1015      1015     1015
# Super Gamer    1020          1020      1020          1020      1020     1020
# Viewer          924           924       924           924       924      924
#
#                created_at  num_shares  game_id  is_ar  id_y
# class
# Creator               963         963      963    963   963
# Gamer                1078        1078     1078   1078  1078
# Super Creator        1015        1015     1015   1015  1015
# Super Gamer          1020        1020     1020   1020  1020
# Viewer                924         924      924    924   924

# %%
videos['duration'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
videos.agg(['count', 'nunique'])
# Out:
#            id  attribute_id  music_id  animation_id  duration  creator  \
# count    5000          5000      5000          5000      5000     5000
# nunique  5000            11        10            15       491      992
#
#          created_at  num_shares  game_id  is_ar
# count          5000        5000     5000   5000
# nunique        5000          21        5      2

# %%
px.histogram(videos, x='duration', color='game_id')
# Out:
# <div>                            <div id="80958a9b-ee00-4f8c-a298-47b23f12c228" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80958a9b-ee00-4f8c-a298-47b23f12c228")) {                    Plotly.newPlot(                        "80958a9b-ee00-4f8c-a298-47b23f12c228",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"game_id=8bd4c7be-fe87-45ad-990d-d131cd3d9c77<br>duration=%{x}<br>count=%{y}<extra></extra>","legendgroup":"8bd4c7be-fe87-45ad-990d-d131cd3d9c77","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"8bd4c7be-fe87-45ad-990d-d131cd3d9c77","offsetgroup":"8bd4c7be-fe87-45ad-990d-d131cd3d9c77","orientation":"v","showlegend":true,"x":[5.34,6.5,5.71,4.08,4.95,4.93,2.14,4.76,6.71,2.59,6.73,6.63,3.64,5.74,3.66,4.31,4.86,4.81,5.28,4.06,3.96,4.83,4.77,3.66,5.8,4.74,3.34,3.46,6.49,6.03,6.76,6.84,4.18,4.13,3.2,6.47,5.08,6.57,4.47,5.56,2.79,4.48,3.84,4.24,5.24,2.82,4.63,2.38,2.59,3.85,5.72,2.93,3.21,3.77,6.31,5.68,6.56,6.44,6.3,4.83,3.12,3.32,2.12,3.22,3.13,3.41,4.19,3.36,4.14,3.78,3.8,6.54,6.98,5.4,4.21,3.37,5.22,2.84,6.35,5.82,5.02,5.95,5.86,5.34,4.75,4.74,3.03,4.8,2.49,4.45,2.17,4.25,5.45,4.72,4.84,4.74,5.8,6.27,5.02,6.93,5.8,5.21,4.98,4.72,5.93,4.92,2.46,2.65,3.81,2.63,5.54,4.39,4.51,2.84,5.43,4.19,2.85,4.44,2.47,2.95,5.83,3.37,2.44,5.6,6.42,3.65,2.24,4.44,2.25,4.66,2.44,6.18,3.59,3.18,3.72,6.17,3.76,4.89,2.45,6.25,5.69,5.65,3.09,4.5,3.11,5.12,4.94,4.4,2.86,4.03,4.65,3.79,4.06,3.37,4.8,4.71,4.58,3.62,5.11,4.19,4.15,2.86,4.7,4.88,6.3,3.79,3.67,2.27,2.42,4.56,5.7,4.96,6.36,6.56,3.32,6.33,6.12,2.4,2.81,5.87,5.92,6.23,3.15,6.18,4.41,2.19,3.44,2.12,5.84,6.69,2.32,6.44,4.7,5.79,6.73,4.39,3.13,6.02,6.28,6.89,4.3,3.23,5.68,4.3,3.03,4.78,2.31,4.55,5.18,6.83,4.86,3.74,5.97,3.97,5.14,5.1,3.24,3.24,3.34,4.6,2.26,4.14,3.67,2.76,3.04,4.32,4.9,2.28,6.74,6.84,4.85,5.87,5.59,6.69,6.76,5.6,4.89,4.74,4.14,2.7,3.06,5.49,6.75,4.25,4.48,4.91,2.62,3.66,6.04,3.01,4.62,4.54,4.13,5.71,3.19,6.49,3.61,2.51,5.23,6.38,5.09,4.82,5.03,5.87,4.64,2.1,4.03,3.93,5.32,4.19,2.81,5.63,2.7,3.09,5.57,5.25,6.53,2.49,5.81,5.24,4.22,2.43,2.59,4.59,5.26,6.03,5.83,5.32,4.97,5.59,4.78,5.95,3.06,4.24,4.33,6.27,6.92,2.63,5.57,5.75,4.18,5.2,5.8,4.04,6.2,2.53,5.38,6.32,6.71,2.87,4.26,6.49,5.32,4.02,6.52,4.63,2.66,3.83,5.09,5.48,3.05,3.35,6.57,2.98,3.72,3.54,3.48,5.72,5.99,6.77,6.07,5.41,6.39,5.39,4.39,4.29,3.97,2.58,4.26,3.08,2.74,4.84,4.79,6.81,4.25,2.89,5.79,2.75,3.09,2.64,3.57,6.61,5.49,4.03,5.75,5.64,3.94,3.61,3.81,5.79,5.53,6.9,3.09,5.56,3.59,6.41,3.28,5.81,4.37,5.46,4.88,5.02,4.72,2.13,3.38,3.98,5.62,4.65,2.79,2.43,3.48,4.77,5.11,5.74,3.67,3.57,5.88,2.51,6.27,3.95,5.16,2.59,4.49,6.6,5.16,6.81,3.29,5.7,6.52,2.87,4.56,5.13,2.64,5.54,5.63,6.05,5.75,6.79,3.7,3.35,2.43,3.65,4.02,3.6,6.11,3.37,5.79,5.07,5.58,5.92,3.77,3.96,2.67,5.2,2.52,4.96,4.03,3.42,3.95,3.2,3.25,4.6,2.49,6.57,5.02,5.41,6.46,5.05,3.08,2.96,3.49,3.96,4.9,3.4,5.2,2.92,5.14,6.82,3.47,6.23,4.04,2.53,3.0,5.64,3.84,2.84,6.91,3.03,2.92,6.5,2.97,5.2,2.47,5.81,2.67,6.75,2.82,6.76,2.49,6.92,3.05,4.5,5.46,2.25,3.69,2.77,4.43,3.66,3.64,5.22,3.61,6.71,2.21,6.56,4.76,3.02,5.26,5.19,5.17,2.94,3.22,6.19,3.38,4.41,5.37,6.76,3.32,2.94,2.74,6.24,3.01,4.82,3.53,5.17,3.51,6.73,5.04,2.22,4.47,5.28,4.96,2.31,4.86,5.0,5.65,2.83,2.69,4.83,4.64,4.45,2.22,6.77,6.7,4.45,2.25,3.05,4.18,6.42,4.75,4.61,2.53,2.3,3.16,5.93,6.89,5.24,2.57,6.6,3.0,4.12,3.53,2.9,5.32,3.68,5.45,2.17,6.19,2.1,3.65,5.1,6.55,5.83,4.05,5.96,4.25,2.56,4.63,5.36,6.76,6.62,2.45,2.15,6.43,5.88,3.54,5.57,5.38,2.41,6.56,2.95,2.37,4.26,6.41,5.87,4.92,6.32,5.07,5.0,4.96,5.19,2.9,5.2,5.11,5.35,3.37,4.22,3.95,6.96,3.73,6.27,3.31,2.4,5.9,4.94,3.45,5.42,5.87,6.94,5.53,6.02,4.01,3.73,3.35,3.26,5.95,5.32,3.26,6.09,5.62,3.43,2.3,6.51,5.12,6.88,4.88,2.8,3.61,3.02,6.61,4.2,5.29,4.27,6.35,6.4,3.19,4.97,6.08,5. ...

# %% [markdown]
# ### Watched Video Data

# %%
watchedVideo = pd.read_csv('data/watchedVideo.csv')
watchedVideo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   50000 non-null  int64
#  1   coordinates  50000 non-null  object
#  2   os           50000 non-null  object
#  3   duration     50000 non-null  float64
#  4   videoId      50000 non-null  object
#  5   userId       50000 non-null  object
#  6   appVersion   50000 non-null  object
#  7   dateTime     50000 non-null  object
#  8   feedId       50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
watchedVideo.agg(['count','nunique'])
# Out:
#          coordinates     os  duration  videoId  userId  appVersion  dateTime  \
# count          50000  50000     50000    50000   50000       50000     50000
# nunique        50000      2       691     5000    1000          10     49649
#
#          feedId
# count     50000
# nunique      10

# %%
watchedVideo = watchedVideo.drop('Unnamed: 0', axis=1)

# %%
df = pd.merge(watchedVideo, feeds[['id','name']], left_on='feedId', right_on='id', how='left')\
    .drop(columns=['feedId','id'])\
    .rename(columns={'name':'feed'})

# %%
right = videos[['id', 'attribute_id', 'music_id', 'animation_id', 'creator',
       'created_at', 'num_shares', 'game_id', 'is_ar']]

# %%
df = pd.merge(df, right, left_on='videoId', right_on='id', how='left')\
    .drop(columns=['id'])

# %%
df.head()
# Out:
#                                      coordinates       os  duration  \
# 0  (Decimal('14.439490'), Decimal('105.291233'))      iOS      3.95
# 1  (Decimal('40.866935'), Decimal('-73.845013'))      iOS      5.95
# 2    (Decimal('48.666850'), Decimal('9.359456'))      iOS      0.69
# 3   (Decimal('5.172365'), Decimal('-74.439009'))  Android      2.81
# 4     (Decimal('4.063707'), Decimal('9.606159'))      iOS      5.88
#
#                                 videoId                                userId  \
# 0  722e110c-2f81-46aa-9c25-4d26fd77519f  317a2bc3-5f95-4d35-9a94-1f2f38424c4f
# 1  cc10d153-37f9-42b5-8d78-2365908acf2b  db031c3d-69e4-4c06-91fe-e9be0a3c173c
# 2  7f3f7fce-f2ec-4dfd-bac8-92dc7865a365  8fb18b66-f548-42a7-b394-c1be963cac29
# 3  8ffc47e3-32ce-4d24-a990-9baac556603b  960fb90e-eddc-478a-a64a-04b9dded3a05
# 4  47e70477-7511-4bd0-801b-1651f951002f  1ce0c003-25e7-473f-8796-0fe04d6c275c
#
#   appVersion             dateTime     feed  \
# 0      2.2.2  2021-08-04 09:39:07  beaches
# 1      2.2.1  2021-07-06 16:32:10    dance
# 2      2.2.0  2021-12-06 01:42:02   sports
# 3      2.1.2  2021-12-04 21:02:50  fashion
# 4      2.1.2  2021-11-28 16:12:39   travel
#
#                            attribute_id                              music_id  \
# 0  30fa7949-1cb6-44b1-9c7b-42c7421fc504  19e4db13-d854-4913-a8ca-3612ee1a6071
# 1  30fa7949-1cb6-44b1-9c7b-42c7421fc504  4ee0de5b-e27f-4d73-a3c6-52cf26e36c54
# 2  c3328117-4129-4d8b-8250-9479e9c6a389  3de11516-8627-47c3-98ab-265b429cac91
# 3  25e7fab9-abfb-4a74-a8cb-c3adbc6e3531  3de11516-8627-47c3-98ab-265b429cac91
# 4  4712e9e6-bef1-4646-b21e-ca5336901bf9  4ee0de5b-e27f-4d73-a3c6-52cf26e36c54
#
#                            animation_id                               creator  \
# 0  ab5dc9f1-deb4-44d4-88ff-62e473a060f4  43e50511-d2be-4b64-b75f-3d1e7bc33fe9
# 1  ab5dc9f1-deb4-44d4-88ff-62e473a060f4  335a3eed-f53c-4daa-87b1-1216e6132cc8
# 2  08dda558-a151-45a2-8e43-1ba6f2891800  7872da48-f390-4ac6-a53c-324a179e7459
# 3  716c02df-bd3a-41c9-b2be-86fb74ff3255  280a7318-4389-4224-952b-74bec71d2e74
# 4  2029f213-1719-4108-8125-25d465cf475d  293bcb6f-c892-43aa-a92a-4729ec3513fb
#
#             created_at  num_shares                               game_id  \
# 0  2021-07-23 22:53:22          16  8bd4c7be-fe87-45ad-990d-d131cd3d9c77
# 1  2021-06-18 00:08:54           5  2609b6b5-3a08-451e-bce5-75fe506559d2
# 2  2021-11-28 01:59:34           7  2609b6b5-3a08-451e-bce5-75fe506559d2
# 3  2021-09-30 17:17:03          20  6ca0f645-a16b-42b0-9dc2-2ae952c83591
# 4  2021-08-11 05:22:30          11  2609b6b5-3a08-451e-bce5-75fe506559d2
#
#    is_ar
# 0  False
# 1   True
# 2   True
# 3   True
# 4  False

# %%
px.histogram(df, x='num_shares', color='is_ar')
# Out:
# <div>                            <div id="0145b581-5e11-470e-98ae-fc897a7b16ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0145b581-5e11-470e-98ae-fc897a7b16ba")) {                    Plotly.newPlot(                        "0145b581-5e11-470e-98ae-fc897a7b16ba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"is_ar=False<br>num_shares=%{x}<br>count=%{y}<extra></extra>","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"x":[16,11,20,16,8,2,6,12,17,4,2,8,20,12,20,0,12,2,0,16,1,3,19,13,2,9,15,16,2,17,9,1,4,15,18,5,15,8,16,1,17,9,2,19,17,2,15,15,11,7,8,3,2,20,16,4,12,2,11,17,7,4,1,16,8,8,12,6,11,12,9,5,11,7,6,1,20,6,12,1,1,7,2,2,1,9,15,18,4,18,5,12,7,4,0,15,17,12,13,13,6,11,12,8,3,12,15,9,7,19,15,13,14,12,6,6,7,8,3,3,11,12,20,9,15,4,9,1,5,18,11,2,3,18,5,17,9,10,6,0,3,14,10,10,6,8,0,10,3,7,5,13,0,6,3,2,5,14,10,2,3,14,11,4,15,18,6,14,19,5,1,8,17,14,11,12,5,0,18,17,10,20,4,12,16,16,11,5,12,11,19,5,13,1,1,19,9,20,9,16,10,2,12,4,6,12,8,0,2,20,3,19,20,4,9,7,1,9,3,1,8,16,12,3,4,12,18,19,5,20,18,9,15,18,1,19,17,13,3,12,4,13,17,10,1,18,5,14,6,8,19,18,5,2,12,5,9,2,14,10,9,0,5,18,10,7,13,15,7,4,3,10,12,5,6,0,20,9,6,0,20,2,16,11,3,10,10,7,7,16,6,20,17,8,7,19,2,5,18,6,1,6,8,18,0,5,4,3,4,11,10,3,12,4,10,1,11,19,2,10,3,3,9,0,9,9,0,7,15,11,19,5,4,8,10,20,14,12,10,11,14,11,14,3,15,0,10,2,14,11,16,17,3,7,2,5,15,20,0,10,18,5,15,14,11,1,15,5,11,15,1,20,0,8,0,20,14,12,11,2,18,14,8,20,4,11,2,5,11,6,9,14,2,3,19,13,6,17,10,19,10,5,15,12,9,17,1,17,15,0,4,20,20,7,11,5,20,4,20,7,0,16,12,9,16,9,20,7,19,0,20,0,9,8,6,5,17,2,7,1,15,1,6,7,1,0,14,7,9,8,3,9,14,2,5,1,6,20,12,18,18,9,12,14,6,15,12,11,17,9,18,14,13,2,9,5,6,11,20,7,15,15,3,6,6,20,12,2,17,7,2,3,20,2,10,9,17,10,3,12,4,14,3,12,11,9,3,12,12,8,8,14,5,6,5,18,1,20,4,20,0,3,1,4,12,13,20,5,5,13,11,10,2,12,17,5,4,7,3,4,2,7,2,8,10,18,10,4,8,3,12,13,15,15,10,12,19,16,19,18,16,10,0,11,15,18,4,4,11,18,8,2,3,5,11,11,3,12,14,5,10,7,9,12,5,20,8,20,1,8,14,15,0,20,13,0,2,9,5,4,5,3,11,19,1,9,13,16,11,17,5,16,15,9,19,5,7,9,4,1,10,5,6,9,20,15,6,6,13,18,6,3,13,14,14,15,18,10,12,6,2,10,18,0,11,0,12,1,1,16,8,10,20,3,8,15,7,9,18,16,2,3,11,12,4,5,5,11,3,18,8,12,2,5,0,19,0,9,2,13,4,8,1,11,0,16,17,7,6,5,0,18,0,11,5,11,15,19,1,16,9,15,20,4,18,8,12,5,2,0,20,5,7,12,0,13,19,17,20,17,1,4,7,8,0,17,9,14,14,9,6,14,1,9,12,11,15,4,18,9,14,12,4,17,17,2,5,10,4,18,0,4,6,7,12,15,16,20,7,0,12,15,16,16,11,0,2,12,10,11,18,16,5,4,18,10,15,16,2,3,6,9,7,10,17,1,8,19,2,12,7,9,6,18,0,1,11,4,19,3,12,8,15,10,8,12,0,7,2,19,13,10,12,18,6,7,14,19,6,4,10,11,10,17,12,12,18,16,16,16,15,10,13,5,7,4,6,4,15,4,19,16,18,4,10,2,18,18,14,11,9,14,16,13,1,7,16,4,12,3,9,12,13,20,0,9,10,15,5,14,11,4,16,13,17,6,6,3,15,3,4,10,6,4,8,20,19,10,19,3,15,0,3,8,6,17,5,5,9,1,3,13,17,6,8,15,14,10,17,18,10,17,7,10,18,2,4,17,8,16,17,16,3,7,5,20,6,13,2,13,8,13,2,7,14,10,7,6,15,14,17,14,1,3,6,19,19,6,5,16,16,1,7,12,8,9,16,17,20,0,0,15,8,15,3,12,19,7,4,16,11,17,7,17,19,12,11,11,13,6,13,0,0,0,17,4,5,16,15,12,12,20,3,11,19,20,17,17,2,19,4,9,4,6,10,18,7,13,1,16,7,5,6,2,20,19,13,18,5,18,10,0,18,2,8,1,5,12,8,14,12,18,20,4,17,0,2,3,0,3,17,7,13,17,11,3,17,19,13,14,11,5,12,7,1,12,3,2,3,6,14,18,19,19,13,7,10,2,10,1,8,17,17,1,10,20,17,1,13,6,1,4,11,4,9,6,17,16,2,6,0,10,4,14,16,12,9,20,8,8,9,14,13,16,11,12,16,1,19,13,12,19,0,17,15,13,17,5,15,2,12,15,1,14,13,8,11,9,3,3,2,13,4,5,17,3,14,19,5,10,18,6,18,19,16,19,7,15,17,5,12,16,11,16,14,18,16,1,9,12,1,15,7,19,11,18,14,6,12,0,4,12,16,5,9,20,0,0,12,12,1,4,3,1,12,17,20,13,1,14,1,3,20,14,13,19,2,5,7,1,17,3,11,9,2,13,17,16,13,1,19,6,11,0,15,1,11,10,6,3,6,7,8,4,6,7,8,6,8,12,15,10,17,19,8,7,9,12,3,18,6,0,15,8,6,16,20,18,6,2,10,4,2,13,16,3,1,17,18,13,20,2,1,14,3,7,4,10,19,1,11,0,12,8,12,19, ...

# %%
px.histogram(df, x='num_shares', color='feed')
# Out:
# <div>                            <div id="925b5e11-be2e-407a-9419-be48a6a87215" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("925b5e11-be2e-407a-9419-be48a6a87215")) {                    Plotly.newPlot(                        "925b5e11-be2e-407a-9419-be48a6a87215",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"feed=beaches<br>num_shares=%{x}<br>count=%{y}<extra></extra>","legendgroup":"beaches","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"beaches","offsetgroup":"beaches","orientation":"v","showlegend":true,"x":[16,16,7,14,3,5,2,1,4,5,3,8,20,19,0,20,7,7,9,7,10,12,3,12,14,4,1,0,3,17,2,15,6,14,8,5,19,1,0,3,14,7,5,17,8,4,17,16,15,7,13,17,8,18,0,8,12,14,8,9,18,19,10,8,15,6,5,18,5,5,10,8,20,19,12,13,9,5,20,0,0,9,16,5,12,6,18,8,7,20,10,14,14,0,13,5,17,2,12,9,6,5,8,3,10,19,3,6,11,15,10,0,12,0,15,0,12,10,11,5,0,17,8,12,7,20,4,4,9,18,18,4,7,3,11,12,11,0,19,7,10,7,17,14,15,17,18,14,16,5,3,1,9,5,13,4,13,4,15,17,10,15,5,8,8,14,12,0,9,19,3,4,6,15,11,7,6,10,1,4,2,18,12,6,9,0,3,19,16,7,13,18,20,13,9,17,12,8,11,20,1,2,19,16,11,15,0,19,0,9,9,17,0,11,2,3,18,10,4,0,12,10,11,14,1,6,0,6,2,12,12,13,3,18,11,5,10,12,11,12,15,11,8,20,15,9,9,4,18,10,12,1,19,2,5,10,5,2,1,10,8,4,7,14,13,12,7,20,6,11,15,0,20,4,6,3,0,7,12,14,8,8,3,0,6,5,9,2,15,15,6,8,0,5,18,2,9,16,3,10,9,14,20,7,11,11,19,13,19,14,7,14,19,7,11,2,20,19,9,7,13,7,11,16,11,16,7,10,3,20,0,20,0,17,6,5,14,15,11,12,9,0,5,3,9,7,11,2,7,17,12,13,1,16,17,15,8,12,5,12,15,17,15,1,18,13,5,7,20,10,6,15,9,2,14,3,19,8,10,16,6,5,5,6,14,6,10,10,7,2,20,1,3,4,10,11,20,20,12,19,5,4,18,19,4,9,17,16,13,11,2,6,20,16,17,15,8,2,15,5,1,6,11,4,17,19,6,4,11,5,15,10,6,7,19,14,17,13,4,15,8,14,14,5,7,13,3,9,12,6,4,0,13,11,0,8,12,1,14,13,12,6,13,15,20,14,4,14,18,7,12,4,14,11,8,4,9,2,16,4,10,13,9,2,6,13,5,16,6,7,5,5,2,13,14,16,18,2,2,15,3,12,20,3,6,4,5,20,9,18,3,20,17,12,2,19,14,20,6,6,19,20,12,12,19,20,2,9,13,2,4,19,18,18,8,5,2,4,2,3,7,11,4,8,12,11,17,8,1,2,3,3,14,3,5,19,10,12,2,2,20,2,2,14,7,12,8,15,15,17,12,1,2,0,14,16,3,8,2,5,6,2,8,11,5,12,8,14,17,2,2,19,10,19,10,15,20,16,19,9,7,6,13,16,7,4,10,18,7,17,3,18,4,1,15,5,15,11,16,10,15,5,1,9,14,11,5,19,16,18,19,12,13,20,20,13,11,15,18,3,15,15,5,0,7,4,8,20,4,2,3,3,8,8,14,11,7,13,10,11,8,10,1,10,18,11,2,17,14,4,5,18,7,11,19,14,8,2,11,5,13,7,5,4,4,0,4,20,20,17,7,15,18,20,6,1,1,11,9,13,6,12,1,11,2,5,0,5,0,0,3,10,0,8,10,12,16,1,5,6,16,1,4,6,2,20,2,14,4,16,12,19,17,14,7,14,3,8,5,14,4,11,9,6,12,4,3,7,11,15,11,5,12,2,11,3,10,15,3,12,18,12,9,6,15,16,0,12,1,11,3,17,19,4,6,12,9,11,1,3,16,17,1,2,4,12,8,7,11,16,2,3,5,12,3,1,18,4,11,12,17,14,14,8,1,8,18,1,2,20,10,1,13,2,0,19,2,11,6,10,10,12,16,3,13,15,15,0,19,0,18,19,0,2,0,15,5,16,15,2,13,12,11,10,8,18,10,14,9,18,17,16,4,4,16,10,0,12,4,18,0,5,20,7,16,12,17,3,4,14,7,3,2,14,0,15,14,6,10,2,8,15,2,2,18,18,15,19,5,12,0,0,4,6,10,4,17,4,8,2,4,12,3,2,11,1,17,18,20,15,18,1,16,7,3,7,0,20,12,9,19,3,19,7,0,20,16,14,11,5,6,4,17,4,20,13,2,8,6,12,9,0,5,14,12,7,1,0,13,17,9,1,17,12,4,20,17,20,7,5,14,20,3,7,1,14,5,6,19,2,5,15,1,10,10,5,13,3,11,2,9,13,20,17,3,12,6,11,16,7,11,14,12,17,13,12,8,7,16,0,7,13,17,1,6,0,15,3,10,11,14,4,13,11,7,15,8,11,2,15,18,15,7,18,15,0,15,15,19,18,0,9,14,2,4,5,20,8,18,0,12,5,7,19,19,12,20,19,11,2,10,5,10,9,13,3,20,11,12,17,18,11,0,2,20,11,18,6,11,16,0,5,14,3,9,8,16,18,18,16,1,7,17,0,11,16,10,10,15,5,9,18,20,15,2,0,2,11,3,2,4,6,13,7,15,20,1,6,9,13,6,14,14,2,1,14,17,6,12,1,1,4,4,17,14,9,3,17,6,5,6,9,19,18,19,18,8,7,18,14,4,2,17,16,5,18,0,19,3,11,20,20,18,7,13,0,1,13,3,5,13,6,12,6,16,15,16,18,1,13,9,12,13,12,18,4,15,5,18,3,2,20,7,4,2,3,15,1,11,19,6,10,9,2,18,16,1,12,12,11,11,14,8,4,19,18,0,16,1,19,7,16,14,6,3,16,15,12,19,10,5,16,12,5,5,1,8,7,17,15,14,7,19,17,12,7,17,1,0,1,9,13,3,12,7,11,8,0,8,11,7,15,4,18,9,15,20,13,20,18,10,7,4,8,18,17,19,5,2,15,19, ...

# %%
px.histogram(df, x='num_shares', color='os')
# Out:
# <div>                            <div id="81c127f9-a00e-41f0-b589-b78317e0fa9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81c127f9-a00e-41f0-b589-b78317e0fa9f")) {                    Plotly.newPlot(                        "81c127f9-a00e-41f0-b589-b78317e0fa9f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"os=iOS<br>num_shares=%{x}<br>count=%{y}<extra></extra>","legendgroup":"iOS","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"iOS","offsetgroup":"iOS","orientation":"v","showlegend":true,"x":[16,5,7,11,4,20,16,12,5,14,9,16,5,17,4,8,20,12,20,0,12,6,14,3,20,19,13,9,16,9,1,15,19,3,8,6,16,1,17,12,9,2,3,17,2,15,11,8,10,8,3,2,4,12,17,4,0,1,6,16,15,12,0,16,7,10,12,1,4,11,8,7,0,1,20,14,10,20,2,6,6,8,2,9,18,9,15,2,6,19,18,7,12,7,0,11,15,17,12,13,13,20,1,9,12,14,3,12,9,8,19,15,13,20,14,6,6,7,1,3,5,12,14,20,4,5,2,5,17,15,2,5,3,13,12,10,6,4,8,0,10,7,5,13,6,3,14,5,11,14,0,2,3,0,14,3,4,4,13,7,0,11,19,5,1,8,15,17,14,11,12,16,0,11,18,9,17,14,6,12,11,15,16,16,12,19,8,15,19,2,9,3,19,7,10,2,4,6,1,2,9,20,3,20,15,9,13,14,3,1,8,7,12,8,18,19,11,16,2,9,18,8,13,9,8,19,12,6,6,13,16,8,1,13,17,10,4,1,4,6,8,17,5,2,12,2,10,2,14,9,7,13,17,10,10,7,6,20,4,9,6,0,2,11,15,17,7,13,16,14,6,14,20,9,8,7,19,2,1,6,14,9,12,18,7,0,20,8,5,14,14,0,18,15,20,11,4,3,10,3,12,15,11,1,16,4,5,4,19,2,3,9,8,0,0,16,2,5,19,5,4,8,13,10,15,15,20,14,12,19,17,0,4,11,14,15,9,0,18,18,4,13,9,16,0,3,6,7,2,20,6,5,10,5,6,15,5,11,15,8,18,13,14,3,0,10,8,12,3,18,11,2,10,18,8,20,16,6,6,20,6,14,0,19,14,12,18,13,6,17,7,10,5,15,12,17,9,1,15,4,17,15,0,4,20,7,11,20,7,5,16,0,19,14,4,19,0,20,9,8,6,1,3,12,1,6,7,0,16,1,14,14,14,3,12,8,2,6,1,6,18,0,9,18,19,6,12,15,12,11,17,18,5,8,3,10,7,17,6,3,6,17,13,11,2,17,7,2,20,14,2,10,9,0,10,13,12,14,3,19,12,12,8,3,5,0,11,18,18,1,17,11,2,20,13,20,0,1,1,5,2,1,12,13,5,4,13,13,2,17,5,7,19,4,11,7,2,10,8,4,15,8,10,3,12,15,10,19,16,5,15,16,10,0,15,12,11,15,0,18,8,4,4,8,18,8,16,14,2,14,6,3,5,11,3,14,5,10,7,12,5,8,7,1,8,0,6,13,0,2,8,4,12,5,11,19,1,12,19,7,18,16,11,17,15,9,19,5,7,9,4,1,10,18,9,20,6,5,6,14,13,14,14,15,18,19,7,8,6,18,12,3,0,12,19,10,1,1,16,11,18,20,3,10,9,18,18,0,16,2,11,12,5,5,5,11,19,18,4,20,17,12,5,2,5,19,0,9,3,4,19,1,11,8,0,4,19,14,13,11,7,2,5,18,2,0,17,11,10,8,11,7,16,4,3,6,15,1,16,9,20,20,1,6,6,8,8,12,5,2,0,5,0,20,7,20,8,3,0,17,9,4,18,16,9,1,12,14,11,15,4,18,2,12,6,14,14,12,4,17,3,17,18,14,4,19,18,4,5,4,6,20,0,12,16,15,14,11,12,0,2,12,10,11,18,16,15,10,18,10,18,12,4,2,3,6,7,10,11,6,17,4,0,1,15,8,7,2,2,12,0,7,6,12,18,3,0,1,11,3,9,15,3,10,8,12,0,7,2,10,11,11,19,19,12,17,2,18,11,6,18,18,6,4,4,10,17,14,1,12,12,14,0,2,16,9,4,15,10,5,2,3,15,4,15,11,16,16,3,4,8,10,18,18,14,11,7,9,0,9,15,10,13,7,20,4,18,9,0,3,9,12,13,0,11,12,13,15,20,20,11,14,0,16,13,17,1,3,15,16,4,10,4,20,19,4,3,3,15,17,0,3,14,17,16,5,12,5,9,14,3,11,10,17,20,17,10,9,10,7,15,3,20,4,14,10,17,8,5,17,3,7,5,20,2,13,20,2,5,8,0,7,20,14,17,12,16,15,14,8,1,3,6,11,16,19,6,5,16,16,1,7,15,10,20,2,1,9,16,16,20,0,14,17,15,5,2,11,20,13,3,20,4,6,4,7,19,12,11,13,1,0,0,0,17,4,5,9,11,20,19,17,17,15,11,5,4,15,10,1,18,7,6,18,15,1,20,19,5,10,0,18,2,2,13,1,9,19,8,14,12,18,20,6,17,0,9,3,17,17,5,19,18,11,3,14,8,8,12,10,0,3,7,6,19,16,13,7,13,10,19,18,1,17,17,20,17,1,12,6,1,6,13,4,6,17,5,7,2,12,6,4,17,16,12,9,14,16,1,19,4,6,15,13,3,13,16,17,12,1,12,2,13,3,8,14,6,13,11,18,18,3,7,15,1,18,3,17,8,0,1,5,13,7,10,2,6,18,19,16,7,12,2,15,17,5,19,15,13,10,12,16,18,19,19,16,18,16,18,3,7,9,9,18,6,11,0,18,5,8,2,12,2,9,0,0,12,8,0,4,3,12,12,20,13,14,1,3,20,13,2,19,5,12,5,9,13,17,17,9,11,2,13,3,16,9,1,0,17,20,16,17,14,2,3,6,7,12,4,0,16,7,16,6,8,11,12,10,17,13,19,2,7,9,8,12,19,6,17,6,0,15,17,14,8,6,16,9,2,10,2,18,20,2,4,7,4,12,6,8,10,7,15,19,1,11,0,12,8,4,6,12,14,9,0,11,3,20,5,14,19,0,9,19,14,6,10,1,3,0,6,7,14,10,6,7,8,12,5,20,16,12,19,4,3,13,4,18,3,20 ...
